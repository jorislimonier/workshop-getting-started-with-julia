# %% [markdown]
# # Homework
# ## Q1

# %%
using RDatasets
using Plots

air_quality = dataset("datasets", "airquality")
# Out:
# 153×6 DataFrame
#  Row │ Ozone    Solar.R  Wind     Temp   Month  Day
#      │ Int64?   Int64?   Float64  Int64  Int64  Int64
# ─────┼────────────────────────────────────────────────
#    1 │      41      190      7.4     67      5      1
#    2 │      36      118      8.0     72      5      2
#    3 │      12      149     12.6     74      5      3
#    4 │      18      313     11.5     62      5      4
#    5 │ missing  missing     14.3     56      5      5
#    6 │      28  missing     14.9     66      5      6
#    7 │      23      299      8.6     65      5      7
#    8 │      19       99     13.8     59      5      8
#    9 │       8       19     20.1     61      5      9
#   10 │ missing      194      8.6     69      5     10
#   11 │       7  missing      6.9     74      5     11
#   ⋮  │    ⋮        ⋮        ⋮       ⋮      ⋮      ⋮
#  144 │      13      238     12.6     64      9     21
#  145 │      23       14      9.2     71      9     22
# ...

# %% [markdown]
# ## Q2

# %%
scatter(
  air_quality[!,"Ozone"],
  air_quality[!, "Solar.R"],
  xlabel="Ozone",
  ylabel="Solar.R",
  legend=false
)

# %% [markdown]
# ## Q3 a

# %%
using Pkg
Pkg.add("DataFrames")

using DataFrames
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\Abrar\.julia\environments\v1.6\Project.toml`
#   No Changes to `C:\Users\Abrar\.julia\environments\v1.6\Manifest.toml`

# %% [markdown]
# ## Q3 b

# %%
ozone = air_quality[!, ["Ozone"]]
# Out:
# 153×1 DataFrame
#  Row │ Ozone
#      │ Int64?
# ─────┼─────────
#    1 │      41
#    2 │      36
#    3 │      12
#    4 │      18
#    5 │ missing
#    6 │      28
#    7 │      23
#    8 │      19
#    9 │       8
#   10 │ missing
#   11 │       7
#   ⋮  │    ⋮
#  144 │      13
#  145 │      23
#  146 │      36
#  147 │       7
#  148 │      14
#  149 │      30
#  150 │ missing
#  151 │      14
#  152 │      18
#  153 │      20
# 132 rows omitted

# %% [markdown]
# ## Q3 c

# %%
exisiting_ozone_values = dropmissing(ozone)
# Out:
# 116×1 DataFrame
#  Row │ Ozone
#      │ Int64
# ─────┼───────
#    1 │    41
#    2 │    36
#    3 │    12
#    4 │    18
#    5 │    28
#    6 │    23
#    7 │    19
#    8 │     8
#    9 │     7
#   10 │    16
#   11 │    11
#   ⋮  │   ⋮
#  107 │    16
#  108 │    13
#  109 │    23
#  110 │    36
#  111 │     7
#  112 │    14
#  113 │    30
#  114 │    14
#  115 │    18
#  116 │    20
# 95 rows omitted

# %% [markdown]
# ## Q3 d

# %%
histogram(
    exisiting_ozone_values[!, "Ozone"],
    xlabel= "Ozone",
    ylabel= "No.",
    Legend = false,
)
